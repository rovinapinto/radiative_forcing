# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import zarr
import gcsfs

xr.set_options(display_style='html')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
plt.rcParams['figure.figsize'] = 12, 6

# %%
df = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')
df.head()
# Out:
# /home/rpinto/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   activity_id institution_id source_id experiment_id member_id table_id  \
# 0  AerChemMIP        AS-RCEC   TaiESM1       histSST  r1i1p1f1   AERmon
# 1  AerChemMIP            BCC  BCC-ESM1       histSST  r1i1p1f1   AERmon
# 2  AerChemMIP            BCC  BCC-ESM1       histSST  r1i1p1f1   AERmon
# 3  AerChemMIP            BCC  BCC-ESM1       histSST  r1i1p1f1   AERmon
# 4  AerChemMIP            BCC  BCC-ESM1       histSST  r1i1p1f1   AERmon
#
#   variable_id grid_label                                             zstore  \
# 0    od550aer         gn  gs://cmip6/AerChemMIP/AS-RCEC/TaiESM1/histSST/...
# 1       mmrbc         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/histSST/r1i...
# 2     mmrdust         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/histSST/r1i...
# 3       mmroa         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/histSST/r1i...
# 4      mmrso4         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/histSST/r1i...
#
#    dcpp_init_year   version
# 0             NaN  20200310
# 1             NaN  20190718
# 2             NaN  20191127
# 3             NaN  20190809
# 4             NaN  20191127

# %%
df.experiment_id.unique()
# Out:
# array(['histSST', 'piClim-CH4', 'piClim-NTCF', 'piClim-control', 'ssp370',
#        'hist-1950HC', 'piClim-2xDMS', 'piClim-2xdust', 'piClim-2xfire',
#        'piClim-2xss', 'piClim-BC', 'piClim-HC', 'piClim-N2O', 'piClim-OC',
#        'piClim-SO2', 'piClim-aer', 'hist-piNTCF', 'hist-piAer',
#        'histSST-1950HC', 'histSST-piAer', 'histSST-piCH4',
#        'histSST-piNTCF', 'histSST-piO3', 'piClim-2xNOx', 'piClim-2xVOC',
#        'piClim-NOx', 'piClim-O3', 'piClim-VOC', 'ssp370-lowNTCF',
#        'ssp370SST-lowCH4', 'ssp370SST-lowNTCF', 'ssp370SST-ssp126Lu',
#        'ssp370SST', 'ssp370pdSST', '1pctCO2-bgc', '1pctCO2-rad',
#        'esm-ssp585', 'hist-bgc', '1pctCO2-cdr', 'esm-pi-CO2pulse',
#        'esm-pi-cdr-pulse', 'amip-4xCO2', 'amip-future4K', 'amip-m4K',
#        'amip-p4K', 'amip', 'abrupt-2xCO2', 'abrupt-solp4p',
#        'abrupt-0p5xCO2', 'amip-lwoff', 'amip-p4K-lwoff', 'aqua-4xCO2',
#        'abrupt-solm4p', 'aqua-control-lwoff', 'aqua-control',
#        'aqua-p4K-lwoff', 'aqua-p4K', '1pctCO2', 'abrupt-4xCO2',
#        'historical', 'piControl', 'esm-hist', 'esm-piControl',
#        'amip-hist', 'esm-piControl-spinup', 'piControl-spinup',
#        'hist-GHG', 'hist-nat', 'hist-aer', 'hist-CO2', 'hist-GHG-cmip5',
#        'hist-aer-cmip5', 'hist-nat-cmip5', 'hist-sol', 'hist-stratO3',
#        'hist-totalO3', 'hist-volc', 'ssp245-GHG', 'ssp245-aer',
#        'ssp245-nat', 'ssp245-stratO3', 'dcppA-hindcast', 'dcppA-assim',
#        'dcppC-hindcast-noAgung', 'dcppC-hindcast-noElChichon',
#        'dcppC-hindcast-noPinatubo', 'dcppC-amv-neg', 'dcppC-amv-pos',
#        'dcppC-amv-ExTrop-neg', 'dcppC-amv-ExTrop-pos',
#        'dcppC-amv-Trop-neg', 'dcppC-amv-Trop-pos', 'dcppC-atl-control',
#        'dcppC-atl-pacemaker', 'dcppC-ipv-NexTrop-neg',
#        'dcppC-ipv-NexTrop-pos', 'dcppC-ipv-neg', 'dcppC-ipv-pos',
#        'dcppC-pac-control', 'dcppC-pac-pacemaker', 'faf-heat',
#        'faf-passiveheat', 'faf-stress', 'faf-water', 'faf-all',
#        'faf-heat-NA0pct', 'faf-heat-NA50pct', 'hist-resIPO',
#        'highresSST-present', 'highresSST-future', 'hist-1950',
#        'control-1950', 'land-hist', 'deforest-globe',
#        'esm-ssp585-ssp126Lu', 'hist-noLu', 'land-noLu',
#        'land-hist-altStartYear', 'ssp126-ssp370Lu', 'ssp370-ssp126Lu',
#        'omip1', 'futSST-pdSIC', 'pdSST-futAntSIC', 'pdSST-futArcSIC',
#        'pdSST-pdSIC', 'pdSST-piAntSIC', 'pdSST-piArcSIC', 'piSST-pdSIC',
#        'piSST-piSIC', 'pa-futArcSIC', 'pa-pdSIC', 'lgm', 'lig127k',
#        'midHolocene', 'past1000', 'piClim-4xCO2', 'piClim-anthro',
#        'piClim-ghg', 'piClim-histall', 'piClim-lu', 'piClim-histaer',
#        'piClim-histghg', 'piClim-histnat', 'ssp126', 'ssp245', 'ssp585',
#        'ssp119', 'ssp434', 'ssp460', 'ssp534-over'], dtype=object)

# %%
df_ta = df.query("activity_id=='RFMIP' & table_id == 'Amon' & variable_id == 'rsdt' & experiment_id == 'piClim-aer'")
df_ta
# Out:
#        activity_id institution_id        source_id experiment_id  member_id  \
# 271705       RFMIP          CCCma          CanESM5    piClim-aer   r1i1p2f1
# 271795       RFMIP   CNRM-CERFACS       CNRM-CM6-1    piClim-aer   r1i1p1f2
# 271879       RFMIP   CNRM-CERFACS      CNRM-ESM2-1    piClim-aer   r1i1p1f2
# 272056       RFMIP           IPSL     IPSL-CM6A-LR    piClim-aer   r1i1p1f1
# 272076       RFMIP           IPSL     IPSL-CM6A-LR    piClim-aer   r2i1p1f1
# 272095       RFMIP           IPSL     IPSL-CM6A-LR    piClim-aer   r3i1p1f1
# 272114       RFMIP           IPSL     IPSL-CM6A-LR    piClim-aer   r4i1p1f1
# 272542       RFMIP          MIROC           MIROC6    piClim-aer  r11i1p1f1
# 272555       RFMIP          MIROC           MIROC6    piClim-aer   r1i1p1f1
# 272723       RFMIP           MOHC  HadGEM3-GC31-LL    piClim-aer   r1i1p1f3
# 272831       RFMIP            MRI       MRI-ESM2-0    piClim-aer   r1i1p1f1
# 272940       RFMIP      NASA-GISS      GISS-E2-1-G    piClim-aer   r1i1p1f1
# 273059       RFMIP           NCAR            CESM2    piClim-aer   r1i1p1f1
# 273129       RFMIP            NCC       NorESM2-LM    piClim-aer   r1i1p1f1
# 273202       RFMIP            NCC       NorESM2-MM    piClim-aer   r1i1p1f1
# 273495       RFMIP      NOAA-GFDL         GFDL-CM4    piClim-aer   r1i1p1f1
#
#        table_id variable_id grid_label  \
# 271705     Amon        rsdt         gn
# 271795     Amon        rsdt         gr
# 271879     Amon        rsdt         gr
# 272056     Amon        rsdt         gr
# 272076     Amon        rsdt         gr
# 272095     Amon        rsdt         gr
# 272114     Amon        rsdt         gr
# 272542     Amon        rsdt         gn
# 272555     Amon        rsdt         gn
# 272723     Amon        rsdt         gn
# 272831     Amon        rsdt         gn
# 272940     Amon        rsdt         gn
# 273059     Amon        rsdt         gn
# 273129     Amon        rsdt         gn
# 273202     Amon        rsdt         gn
# 273495     Amon        rsdt        gr1
#
#                                                    zstore  dcpp_init_year  \
# 271705  gs://cmip6/RFMIP/CCCma/CanESM5/piClim-aer/r1i1...             NaN
# 271795  gs://cmip6/RFMIP/CNRM-CERFACS/CNRM-CM6-1/piCli...             NaN
# 271879  gs://cmip6/RFMIP/CNRM-CERFACS/CNRM-ESM2-1/piCl...             NaN
# 272056  gs://cmip6/RFMIP/IPSL/IPSL-CM6A-LR/piClim-aer/...             NaN
# 272076  gs://cmip6/RFMIP/IPSL/IPSL-CM6A-LR/piClim-aer/...             NaN
# 272095  gs://cmip6/RFMIP/IPSL/IPSL-CM6A-LR/piClim-aer/...             NaN
# 272114  gs://cmip6/RFMIP/IPSL/IPSL-CM6A-LR/piClim-aer/...             NaN
# 272542  gs://cmip6/RFMIP/MIROC/MIROC6/piClim-aer/r11i1...             NaN
# 272555  gs://cmip6/RFMIP/MIROC/MIROC6/piClim-aer/r1i1p...             NaN
# 272723  gs://cmip6/RFMIP/MOHC/HadGEM3-GC31-LL/piClim-a...             NaN
# 272831  gs://cmip6/RFMIP/MRI/MRI-ESM2-0/piClim-aer/r1i...             NaN
# 272940  gs://cmip6/RFMIP/NASA-GISS/GISS-E2-1-G/piClim-...             NaN
# 273059  gs://cmip6/RFMIP/NCAR/CESM2/piClim-aer/r1i1p1f...             NaN
# 273129  gs://cmip6/RFMIP/NCC/NorESM2-LM/piClim-aer/r1i...             NaN
# 273202  gs://cmip6/RFMIP/NCC/NorESM2-MM/piClim-aer/r1i...             NaN
# 273495  gs://cmip6/RFMIP/NOAA-GFDL/GFDL-CM4/piClim-aer...             NaN
#
#          version
# 271705  20190429
# 271795  20190621
# 271879  20190219
# 272056  20190118
# 272076  20190118
# 272095  20190118
# 272114  20190118
# 272542  20190807
# 272555  20190705
# 272723  20191113
# 272831  20200114
# 272940  20191003
# 273059  20191205
# 273129  20190815
# 273202  20200206
# 273495  20180701
